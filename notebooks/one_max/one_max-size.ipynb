# %% [markdown]
# ```
#   _________ ____________  ___
#  /   _____//  _____/\   \/  /  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  \_____  \/   \  ___ \     /   THE E(X)TENDED (S)ELFISH (G)ENE ALGORITHM
#  /        \    \_\  \/     \   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /_________/\________/___/\  \  https://github.com/squillero/sgx
#                           \_/
# ```

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import sys
sys.path += ['../src']
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s: %(message)s', datefmt='%H:%M:%S')
logging.getLogger().setLevel(logging.INFO)
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
DB_NAME = 'one-max_size'

# %%
results = pd.read_sql_table(table_name='base', con=f'sqlite:///{DB_NAME}.sqlite3')

# %%
plt.figure(figsize=(16, 6))
ax = sns.barplot(data=results, x='Size', y='Fitness Calls', hue='Allele')
ax.set_title("Std_learning_rate_0.1")
# Out:
# Text(0.5, 1.0, 'Std_learning_rate_0.1')

# %%
plt.figure(figsize=(16, 6))
ax = sns.barplot(data=results, x='Size', y='Generations', hue='Allele')
ax.set_title("Std_learning_rate_0.1")
# Out:
# Text(0.5, 1.0, 'Std_learning_rate_0.1')
